# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Data/retail_sales_data.csv')

# %%
df
# Out:
#           Date  Product_ID Product_Name     Category  Sales_Price  Cost_Price  \
# 0   2023-01-01        1001    Product A  Electronics          500         350
# 1   2023-01-02        1002    Product B  Electronics          600         400
# 2   2023-01-03        1003    Product C     Clothing           50          30
# 3   2023-01-04        1004    Product D     Clothing           40          25
# 4   2023-01-05        1005    Product E   Home Decor          100          70
# 5   2023-01-06        1006    Product F   Home Decor          120          80
# 6   2023-01-07        1007    Product G  Electronics          450         300
# 7   2023-01-08        1008    Product H  Electronics          550         380
# 8   2023-01-09        1009    Product I     Clothing           60          35
# 9   2023-01-10        1010    Product J     Clothing           45          28
# 10  2023-01-11        1011    Product K   Home Decor          110          75
# ...

# %%
df.head()
# Out:
#          Date  Product_ID Product_Name     Category  Sales_Price  Cost_Price  \
# 0  2023-01-01        1001    Product A  Electronics          500         350
# 1  2023-01-02        1002    Product B  Electronics          600         400
# 2  2023-01-03        1003    Product C     Clothing           50          30
# 3  2023-01-04        1004    Product D     Clothing           40          25
# 4  2023-01-05        1005    Product E   Home Decor          100          70
#
#    Quantity_Sold  Inventory_Count
# 0             20              100
# 1             15               80
# 2             50              200
# 3             80              120
# 4             30              150

# %%
Category_Sales_Revenue = df.groupby(["Category"])[["Sales_Price"]].sum()
print(Category_Sales_Revenue)
# Out:
#              Sales_Price
# Category
# Clothing             819
# Electronics         8560
# Home Decor          1930

# %%
x = ["Clothing", "Electronics", "Home Decor"]
y = [819, 8560, 1930]

# %%
plt.bar(x,y)
plt.show()

# %%
Category = ["Clothing", "Electronics", "Home Decor"]
Total_Sales_Revenue = [819, 8560, 1930]

# %%
plt.style.use('tableau-colorblind10')

plt.bar(Category,Total_Sales_Revenue,color="b")


plt.xlabel("Category")
plt.ylabel("Total Sales Revenue")

plt.tight_layout()
plt.grid(False)

plt.show()

# %%
df.groupby(["Product_Name"])[["Quantity_Sold"]].sum()
# Out:
#               Quantity_Sold
# Product_Name
# Product A                85
# Product B                72
# Product C               211
# Product D               305
# Product E               130
# Product F               116
# Product G                71
# Product H                97
# Product I               171
# Product J               276
# Product K               147
# Product L               111

# %%
df.nlargest(5, 'Quantity_Sold')
# Out:
#           Date  Product_ID Product_Name  Category  Sales_Price  Cost_Price  \
# 3   2023-01-04        1004    Product D  Clothing           40          25
# 15  2023-02-04        1004    Product D  Clothing           42          25
# 27  2023-03-04        1004    Product D  Clothing           44          25
# 21  2023-02-10        1010    Product J  Clothing           47          28
# 39  2023-04-04        1004    Product D  Clothing           46          25
#
#     Quantity_Sold  Inventory_Count
# 3              80              120
# 15             78              110
# 27             75              100
# 21             72               95
# 39             72               80

# %%
df.groupby(["Date"]).sum()
# Out:
#             Product_ID Product_Name     Category  Sales_Price  Cost_Price  \
# Date
# 2023-01-01        1001    Product A  Electronics          500         350
# 2023-01-02        1002    Product B  Electronics          600         400
# 2023-01-03        1003    Product C     Clothing           50          30
# 2023-01-04        1004    Product D     Clothing           40          25
# 2023-01-05        1005    Product E   Home Decor          100          70
# 2023-01-06        1006    Product F   Home Decor          120          80
# 2023-01-07        1007    Product G  Electronics          450         300
# 2023-01-08        1008    Product H  Electronics          550         380
# 2023-01-09        1009    Product I     Clothing           60          35
# 2023-01-10        1010    Product J     Clothing           45          28
# 2023-01-11        1011    Product K   Home Decor          110          75
# 2023-01-12        1012    Product L   Home Decor          130          85
# ...

# %%
df.groupby(["Date"])[["Sales_Price"]].sum()
# Out:
#             Sales_Price
# Date
# 2023-01-01          500
# 2023-01-02          600
# 2023-01-03           50
# 2023-01-04           40
# 2023-01-05          100
# 2023-01-06          120
# 2023-01-07          450
# 2023-01-08          550
# 2023-01-09           60
# 2023-01-10           45
# 2023-01-11          110
# 2023-01-12          130
# 2023-02-01          520
# 2023-02-02          610
# 2023-02-03           55
# 2023-02-04           42
# 2023-02-05          105
# 2023-02-06          125
# 2023-02-07          460
# 2023-02-08          540
# 2023-02-09           58
# 2023-02-10           47
# 2023-02-11          115
# 2023-02-12          135
# 2023-03-01          510
# 2023-03-02          590
# 2023-03-03           52
# 2023-03-04           44
# 2023-03-05          102
# 2023-03-06          122
# 2023-03-07          470
# 2023-03-08          560
# 2023-03-09           62
# 2023-03-10           49
# 2023-03-11          120
# 2023-03-12          140
# 2023-04-01          530
# ...

# %%
df.dtypes
# Out:
# Date               object
# Product_ID          int64
# Product_Name       object
# Category           object
# Sales_Price         int64
# Cost_Price          int64
# Quantity_Sold       int64
# Inventory_Count     int64
# dtype: object

# %%
df.loc[0, 'Date'].split()
# Out:
# ['2023-01-01']

# %%
df['Date'].str.split()
# Out:
# 0     [2023-01-01]
# 1     [2023-01-02]
# 2     [2023-01-03]
# 3     [2023-01-04]
# 4     [2023-01-05]
# 5     [2023-01-06]
# 6     [2023-01-07]
# 7     [2023-01-08]
# 8     [2023-01-09]
# 9     [2023-01-10]
# 10    [2023-01-11]
# 11    [2023-01-12]
# 12    [2023-02-01]
# 13    [2023-02-02]
# 14    [2023-02-03]
# 15    [2023-02-04]
# 16    [2023-02-05]
# 17    [2023-02-06]
# 18    [2023-02-07]
# 19    [2023-02-08]
# 20    [2023-02-09]
# 21    [2023-02-10]
# 22    [2023-02-11]
# 23    [2023-02-12]
# 24    [2023-03-01]
# 25    [2023-03-02]
# 26    [2023-03-03]
# 27    [2023-03-04]
# 28    [2023-03-05]
# 29    [2023-03-06]
# 30    [2023-03-07]
# 31    [2023-03-08]
# 32    [2023-03-09]
# 33    [2023-03-10]
# 34    [2023-03-11]
# 35    [2023-03-12]
# 36    [2023-04-01]
# 37    [2023-04-02]
# 38    [2023-04-03]
# 39    [2023-04-04]
# 40    [2023-04-05]
# 41    [2023-04-06]
# 42    [2023-04-07]
# 43    [2023-04-08]
# 44    [2023-04-09]
# 45    [2023-04-10]
# 46    [2023-04-11]
# ...

# %%
date = "2023-01-01"

date_mod = date.split("-")

# %%
Month = [January, Feburary, March, April]

Sales_price = []
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 Month = [January, Feburary, March, April]
#       3 Sales_price = []
#
# NameError: name 'January' is not defined

# %%
plt.plot(Total Sales Revenue,Month)
plt.xlabel("Total Sales Revenue")
plt.ylabel("Month")
plt.show()


plt.plot(Date,Sales_Price)
plt.show()
# Out:
#   Cell In[38], line 1
#     plt.plot(Total Sales Revenue,Month)
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df = pd.read_csv("Data/retail_sales_data.csv")

df.head()
# Out:
#          Date  Product_ID Product_Name     Category  Sales_Price  Cost_Price  \
# 0  2023-01-01        1001    Product A  Electronics          500         350
# 1  2023-01-02        1002    Product B  Electronics          600         400
# 2  2023-01-03        1003    Product C     Clothing           50          30
# 3  2023-01-04        1004    Product D     Clothing           40          25
# 4  2023-01-05        1005    Product E   Home Decor          100          70
#
#    Quantity_Sold  Inventory_Count
# 0             20              100
# 1             15               80
# 2             50              200
# 3             80              120
# 4             30              150

# %%
df.loc[0, "Date"].split("-")[1]
# Out:
# '01'

# %%
for i in range(47):
    print(df.loc[i, "Date"].split("-")[1])
# Out:
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 02
# 02
# 02
# 02
# 02
# 02
# 02
# 02
# 02
# 02
# 02
# 02
# 03
# 03
# 03
# 03
# 03
# 03
# 03
# 03
# 03
# 03
# 03
# 03
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04

# %%
df["Date"].str.split
# Out:
# <bound method StringMethods.split of <pandas.core.strings.accessor.StringMethods object at 0x7ff7968148d0>>

# %%
df["Months"] = df["Date"].str.split("-")

# %%
from datetime import date

# %%
pd.to_datetime(df.loc[0, "Date"])
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
date.month
# Out:
# <attribute 'month' of 'datetime.date' objects>

# %%
date.year
# Out:
# <attribute 'year' of 'datetime.date' objects>

# %%
df["Months"] = pd.to_datetime(df.loc[4, "Date"]).month

# %%
df.head()
# Out:
#          Date  Product_ID Product_Name     Category  Sales_Price  Cost_Price  \
# 0  2023-01-01        1001    Product A  Electronics          500         350
# 1  2023-01-02        1002    Product B  Electronics          600         400
# 2  2023-01-03        1003    Product C     Clothing           50          30
# 3  2023-01-04        1004    Product D     Clothing           40          25
# 4  2023-01-05        1005    Product E   Home Decor          100          70
#
#    Quantity_Sold  Inventory_Count  Months
# 0             20              100       1
# 1             15               80       1
# 2             50              200       1
# 3             80              120       1
# 4             30              150       1

# %%
for i in range(47):
    print(df.loc[i, "Date"].split("-")[1])
# Out:
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 02
# 02
# 02
# 02
# 02
# 02
# 02
# 02
# 02
# 02
# 02
# 02
# 03
# 03
# 03
# 03
# 03
# 03
# 03
# 03
# 03
# 03
# 03
# 03
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04

# %%
df["Date"].str.split("-")[0][1]
# Out:
# '01'

# %%
date = pd.to_datetime(df["Date"])[0]

date
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
date.to_period("m")
# Out:
# Period('2023-01', 'M')

# %%
df["Date_2"] = pd.to_datetime(df["Date"])

# %%
df['Profit/Loss'] = df['Sales_Price'] - df['Cost_Price']

# %%
df['Sales_Price'].subtract(df['Cost_Price'])
# Out:
# 0     150
# 1     200
# 2      20
# 3      15
# 4      30
# 5      40
# 6     150
# 7     170
# 8      25
# 9      17
# 10     35
# 11     45
# 12    170
# 13    210
# 14     25
# 15     17
# 16     35
# 17     45
# 18    160
# 19    160
# 20     23
# 21     19
# 22     40
# 23     50
# 24    160
# 25    190
# 26     22
# 27     19
# 28     32
# 29     42
# 30    170
# 31    180
# 32     27
# 33     21
# 34     45
# 35     55
# 36    180
# 37    220
# 38     24
# 39     21
# 40     38
# 41     48
# 42    180
# 43    190
# 44     29
# 45     23
# 46     50
# 47     60
# dtype: int64

# %%
df2 = df['Sales_Price'].subtract(df['Cost_Price'])

# %%
df2.max()
# Out:
# 220

# %%
Sales_Price = [500,600,50,40,100,120,450,550,60,45,110,130,520,610,55,42,105,125,460,540,58,47,115,135,510,590,52,44,102,122,470,560,62,49,120,140,530,620,54,46,108,128,480,570,64,51,125,145]

plt.style.use("fivethirtyeight")

plt.hist(Sales_Price,color="b",edgecolor="black")

plt.xlabel("Sales Price")
plt.ylabel("Frequency")

plt.tight_layout()
plt.grid(False)
plt.show()

# %%
df['Date'].max()
# Out:
# '2023-04-12'

# %%
df['Date].()
# Out:
#   Cell In[151], line 1
#     df['Date].min()
#        ^
# SyntaxError: unterminated string literal (detected at line 1)
